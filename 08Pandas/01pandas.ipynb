# %% [markdown]
# Pandas- Data analysis and maipulation tool
#
# It is built on top of numpy

# %%
import pandas as pd

# %% [markdown]
# Series- 1D labeled array
# Dataframe- 2D labeled array

# %%
info={
    "name":["Rahul","Harsh","Pom"],
    "CGPA":[9.3,8.1,7.9]
}

df=pd.DataFrame(info)
print(df)
# Out:
#     name  CGPA
# 0  Rahul   9.3
# 1  Harsh   8.1
# 2    Pom   7.9

# %%
print("HOO")
# Out:
# HOO
