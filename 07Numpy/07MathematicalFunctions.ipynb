# %% [markdown]
# Aggrate functions

# %%
import numpy as np

arr=np.array([1,2,3,4,5])

print(np.sum(arr))
print(np.prod(arr))
print(np.min(arr))
print(np.max(arr))
print(np.argmin(arr))
print(np.argrmax(arr))
