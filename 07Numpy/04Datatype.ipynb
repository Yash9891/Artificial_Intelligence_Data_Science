# %%
#data type
import numpy as np

# int8, int16, int32, int64
# to save space we can use int8 to increse performance

arr=np.array([1,2,3,4,5,"pr"]) # if we add a string it will become string type
print(arr.dtype)

#Complex num= 2+3i
# Out:
# <U21

# %%
# complex num  = 2+3i

arr1=np.array([3+5j])
arr2=np.array([3+5j])
print((arr1+arr2, arr.dtype))
# Out:
# (array([6.+10.j]), dtype('complex128'))

# %%
# we do not prefer to store string and obj in numpy

arr=np.array(["prime",{1,2,3,4,},3.21])
print(arr.dtype)
# Out:
# object
