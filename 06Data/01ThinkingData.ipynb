# %%
print("Godzillaa is coming")
# Out:
# Godzillaa is coming

# %%
a=5
print(a+34)
# Out:
# 39

# %% [markdown]
# ctl+enter= run the cell does not create new cell
# shift+enter= run and create new cell
